# %%
import pandas as pd
dataset = pd.read_csv("heart.csv")
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # Анализ данных

# %%
import pandas as pd
dataset = pd.read_csv("heart.csv")
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# # Нормализация значений в наборе данных

# %%
for column in dataset.columns:
    if column != "heart":
        dataset[column] = (dataset[column] - dataset[column].min()) / (dataset[column].max() - dataset[column].min())


dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528465    0.683168    0.322332    0.354941    0.274575    0.264026
# std      0.189210    0.466011    0.344017    0.165454    0.118335    0.262930
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.385417    0.000000    0.000000    0.245283    0.194064    0.000000
# 50%      0.541667    1.000000    0.333333    0.339623    0.260274    0.500000
# 75%      0.666667    1.000000    0.666667    0.433962    0.339041    0.500000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.600358    0.326733    0.167678    0.699670    0.182343    0.771177
# std      0.174849    0.469794    0.187270    0.308113    0.255652    0.204092
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.477099    0.000000    0.000000    0.500000    0.000000    0.666667
# 50%      0.625954    0.000000    0.129032    0.500000    0.000000    0.666667
# 75%      0.725191    1.000000    0.258065    1.000000    0.250000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            target
# count  303.000000
# mean     0.544554
# std      0.498835
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# # Проверка данный на корреляцию

# %%
dataset.corr()
# Out:
#                age       sex        cp  trestbps      chol   restecg  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678 -0.116211
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912 -0.058196
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.044421
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174 -0.114103
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000 -0.151040
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040  1.000000
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940  0.044123
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023 -0.070733
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952 -0.058770
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038  0.093045
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511 -0.072042
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.011981
# target   -0.225439 -0.280937  0.433798 -0.144931 -0.085239  0.137230
#
#            thalach     exang   oldpeak     slope        ca      thal    target
# age      -0.398522  0.096801  0.210013 -0.168814  0.276326  0.068001 -0.225439
# sex      -0.044020  0.141664  0.096093 -0.030711  0.118261  0.210041 -0.280937
# cp        0.295762 -0.394280 -0.149230  0.119717 -0.181053 -0.161736  0.433798
# trestbps -0.046698  0.067616  0.193216 -0.121475  0.101389  0.062210 -0.144931
# chol     -0.009940  0.067023  0.053952 -0.004038  0.070511  0.098803 -0.085239
# restecg   0.044123 -0.070733 -0.058770  0.093045 -0.072042 -0.011981  0.137230
# thalach   1.000000 -0.378812 -0.344187  0.386784 -0.213177 -0.096439  0.421741
# exang    -0.378812  1.000000  0.288223 -0.257748  0.115739  0.206754 -0.436757
# oldpeak  -0.344187  0.288223  1.000000 -0.577537  0.222682  0.210244 -0.430696
# slope     0.386784 -0.257748 -0.577537  1.000000 -0.080155 -0.104764  0.345877
# ca       -0.213177  0.115739  0.222682 -0.080155  1.000000  0.151832 -0.391724
# thal     -0.096439  0.206754  0.210244 -0.104764  0.151832  1.000000 -0.344029
# target    0.421741 -0.436757 -0.430696  0.345877 -0.391724 -0.344029  1.000000

# %%
table = dataset.corr()
for column in table.columns:
    counter = 0
    for element in table[column]:
        if 1 > abs(element) > 0.5:
            counter += 1
    print(column, counter)
# Out:
# age 0
# sex 0
# cp 0
# trestbps 0
# chol 0
# restecg 0
# thalach 0
# exang 0
# oldpeak 1
# slope 1
# ca 0
# thal 0
# target 0

# %%
dataset.pop('slope')
dataset.pop('oldpeak')
# Out:
# 0      0.370968
# 1      0.564516
# 2      0.225806
# 3      0.129032
# 4      0.096774
#          ...
# 298    0.032258
# 299    0.193548
# 300    0.548387
# 301    0.193548
# 302    0.000000
# Name: oldpeak, Length: 303, dtype: float64

# %% [markdown]
# # Разделение данных на тренировочные и тестовые

# %%
train = dataset.copy()

# %%
test = dataset.copy()
test = test['target']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train, test,test_size=0.2)

# %% [markdown]
# # Тренировка, обучение и проверка модели

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
y_train.head()
# Out:
# 87     1.0
# 229    0.0
# 215    0.0
# 201    0.0
# 135    1.0
# Name: target, dtype: float64

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
predictions = model.predict(x_test)

from sklearn import metrics
print(metrics.accuracy_score(y_test, predictions))
# Out:
# 1.0

# %%
prediction_table = pd.DataFrame(data=predictions)
prediction_table.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
y_test.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Пользовательский ввод

# %%
import numpy as np

raw_dataset = pd.read_csv("heart.csv")

test_value = np.array([])
for column in x_train.columns:
    x = float(input(f"Enter the value for {column}: "))
    x = (x - raw_dataset[column].min()) / (raw_dataset[column].max() - raw_dataset[column].min())
    test_value = np.append(
        test_value,
        x
    )

test_value = test_value.reshape(-1, 1)
# Out:
# Enter the value for age: 50
# Enter the value for sex: 1
# Enter the value for cp: 1
# Enter the value for trestbps: 130
# Enter the value for chol: 220
# Enter the value for restecg: 1
# Enter the value for thalach: 160
# Enter the value for exang: 0
# Enter the value for ca: 0
# Enter the value for thal: 1
# Enter the value for target: 1

# %%
result = model.predict(test_value)
print(result[0])
# Out:
# 0.0
